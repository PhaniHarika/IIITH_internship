# %% [markdown]
# <a href="https://colab.research.google.com/github/PhaniHarika/IIITH_internship/blob/main/TASK_5_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![val_batch0_pred.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![R_curve.png](data:image/png;base64,...)![PR_curve.png](data:image/png;base64,...)![P_curve.png](data:image/png;base64,...)![labels.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![confusion_matrix_normalized.png](data:image/png;base64,...)
